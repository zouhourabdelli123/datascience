# %%
#importer le jeu de donnée
import pandas as pd

data = pd.read_csv('Salary_Data.csv')

# %%
data
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
data.shape
#9adeh fiha min lignie wcolonne
# Out:
# (30, 2)

# %%
#bch n9sam basa x => vusialisation w y  => resultat
x=data.iloc[:,0:1]
x
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
y=data.iloc[:,1]
y
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
#bch nara famechy donner manquante
data.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
data.boxplot(column="YearsExperience")
# Out:
# <Axes: >

# %%
#bch naraha gaussiere walla
import matplotlib.pyplot as plt
#tgim ta3mil bil for wt5dm 3ala 10 
for i in range (2,11):
    x.hist(bins=i)
    plt.title("YearsExperience avec bins "+str(i))
    plt.show()

# %%
#nara symétrique walla
from scipy import stats
skew=stats.skew(x)
print('Skewness x:',skew)
# Out:
# Skewness x: [0.36031233]

# %%
#lezmou ykoun 0 
#tarah negligable ken ili histg ya3tik symétrique
#bima2ennou mouch 0 lezem na3mil il calcule
#he4om ezouz 9rab lil 0 donc rahi meyla il courbe lil ysar
#taw bch nara type de courbe
from scipy.stats import kurtosis
#kurtosis ya3tik i4a pointue walla tal3a mrte7a walla presque droit
a=kurtosis(x)
print('kurtosis x:',a)#lezem nzidha 3 bch ne5ou descision
# Out:
# kurtosis x: [-1.0447522]

# %%
#he4om presque 2 b3id yeser 3al 3 
#ya3ni presque droit
#deja rineha fel salary bins 4 presque plate
#il basa fiha a9all min 50 lignie donc lezem n5tar bin shapliro wd'Agostino
#a9all min 20 shapliro 
#Agostino bin 20 w50
normaltest_stat, normaltest_p = stats.normaltest(x)
print("\nD'Agostino et Pearson test:")
print(f"Statistique X = {normaltest_stat}, p-value = {normaltest_p}")
# Out:
# D'Agostino et Pearson test:
# Statistique X = [3.8083064], p-value = [0.14894872]

# %%
#jetni 0.14894872 9riba lil 0.05% bch nzid shapliro
from scipy.stats import shapiro
shapiro(x.dropna())
#jetni 0.1 zeda >0.05
#=> ya3tini gaussier par conter fel histg majech gaussiere la skoness la chay
#5ater mahiyech 100% gaussiere 10% gaussiere khaw
# Out:
# ShapiroResult(statistic=0.9420625539372643, pvalue=0.10337645734315726)

# %%
normaltest_stat, normaltest_p = stats.normaltest(y)
print("\nD'Agostino et Pearson test:")
print(f"Statistique Y= {normaltest_stat}, p-value = {normaltest_p}")
# Out:
# D'Agostino et Pearson test:
# Statistique Y= 8.032975245813876, p-value = 0.01801613339308227

# %%
data.boxplot(column="Salary")
# Out:
# <Axes: >

# %%
#bch naraha gaussiere walla
import matplotlib.pyplot as plt
#tgim ta3mil bil for wt5dm 3ala 10 
for i in range (2,11):
    y.hist(bins=i)
    plt.title("Salary avec bins "+str(i))
    plt.show()

# %%
#nara symétrique walla
skew=stats.skew(y)
print('Skewness y:',skew)
# Out:
# Skewness y: 0.3361618825592921

# %%
#lezmou ykoun 0 
#tarah negligable ken ili histg ya3tik symétrique
#bima2ennou mouch 0 lezem na3mil il calcule
#he4om ezouz 9rab lil 0 donc rahi meyla il courbe lil ysar
#taw bch nara type de courbe
a=kurtosis(y)
print('kurtosis y:',a)#lezem nzidha 3 bch ne5ou descision
# Out:
# kurtosis y: -1.2829125042427751

# %%
#he4om presque 2 b3id yeser 3al 3 
#ya3ni presque droit
#deja rineha fel salary bins 4 presque plate
#il basa fiha a9all min 50 lignie donc lezem n5tar bin shapliro wd'Agostino
#a9all min 20 shapliro 
#Agostino bin 20 w50
normaltest_stat, normaltest_p = stats.normaltest(y)
print("\nD'Agostino et Pearson test:")
print(f"Statistique Y = {normaltest_stat}, p-value = {normaltest_p}")
# Out:
# D'Agostino et Pearson test:
# Statistique Y = 8.032975245813876, p-value = 0.01801613339308227

# %%
#jetni 0.01801613339308227 9riba lil 0.05% bch nzid shapliro
shapiro(y.dropna())
#jetni 0.015 zeda <0.05
#=> ya3tini mouch gaussier
# Out:
# ShapiroResult(statistic=0.9103154593927696, pvalue=0.015155591078390984)

# %%
#n7ib nktb y en fct de x
#bch ntasty i4a droit walla
plt.scatter(x,y,color='red')
plt.title('Salary vs Experience')
plt.xlabel('Years of experience')
plt.ylabel('Salary')
#5arget presque droit
#il but n5arag model bch kitgibli nhar e5er personne 3andou nb d"expérience njim n9oul chnouwa salairou
# Out:
# Text(0, 0.5, 'Salary')

# %%
#tawa bch n5arag droit ta3tini a9all erreure momknaa
#mthd SLR=>minder carré
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=1.0/3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train,y_train)
y_pred = reg.predict(x_test)
print('y_pred:',y_pred)
print('y_test:',y_test)
# Out:
# y_pred: [ 40835.10590871 123079.39940819  65134.55626083  63265.36777221
#  115602.64545369 108125.8914992  116537.23969801  64199.96201652
#   76349.68719258 100649.1375447 ]
# y_test: 2      37731.0
# 28    122391.0
# 13     57081.0
# 10     63218.0
# 26    116969.0
# 24    109431.0
# 27    112635.0
# 11     55794.0
# 17     83088.0
# 22    101302.0
# Name: Salary, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.scatter(x_test, y_test, color='red')  
plt.plot(x_test, y_pred)   
plt.show()
#graphiquement ma9boul bch nthabat bil calcule

# %%
from sklearn.metrics import mean_squared_error
#moyenne squere errore
mse = mean_squared_error(y_test, y_pred)
print("Erreur quadratique moyenne (MSE):", mse)
#7sbt il erreure bin y_test w y_pred
# Out:
# Erreur quadratique moyenne (MSE): 21026037.329511296

# %%
#3malt keka bch na7i il valeur au carré ili 7sbt bih
import numpy as np
rmse=np.sqrt(mse)
#ou mse**0.5

# %%
#lezem na9smouha 3al np.std ken < 5% => negligable snn laa
rest=rmse/np.std(y_test)
rest
# manjmch n9bilha 5ater erreur kbira >5%
# Out:
# 0.1583810570401801

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)
reg.fit(x_train,y_train)
y_pred = reg.predict(x_test)
print('y_pred:',y_pred)
print('y_test:',y_test)
mse = mean_squared_error(y_test, y_pred)
print("Erreur quadratique moyenne (MSE):", mse)
rmse=np.sqrt(mse)
print("sqrt(mse):", rmse)
rest=rmse/np.std(y_test)
print("rest:", rest)
#il erreure ta7t
# Out:
# y_pred: [ 40748.96184072 122699.62295594  64961.65717022  63099.14214487
#  115249.56285456 107799.50275317]
# y_test: 2      37731.0
# 28    122391.0
# 13     57081.0
# 10     63218.0
# 26    116969.0
# 24    109431.0
# Name: Salary, dtype: float64
# Erreur quadratique moyenne (MSE): 12823412.298126549
# sqrt(mse): 3580.979237321343
# rest: 0.10876802963589055

# %%
#bch nara anehi a7san teste seize bin 15 w 30
from sklearn.metrics import mean_squared_error

find=0
for i in range (15,30):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=i/100, random_state=0)
    reg.fit(x_train,y_train)
    y_pred = reg.predict(x_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rest=rmse/np.std(y_test)
    if rest<0.05 :
        find=1
        print('le modele parfait par ',i,'de teste avec ',rest,'erreure' )
        break
if find==0:
    print('pas de modele')
# Out:
# pas de modele

# %%
#ma9it 7atta wa7da nimchi lil tari9a lo5ra nbadal fel random_state bch niktafi 7atta lil 1000
find=0
for j in range (0,1000):
    for i in range (15,30):
        x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=i/100, random_state=j)
        reg.fit(x_train,y_train)
        y_pred = reg.predict(x_test)
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        rest=rmse/np.std(y_test)
        print('le modele  par test_size ',i,'et random_state ',j,' qui donne un  ',rest,'erreure' ,'avec un rmse ',rmse)
        if rest<0.05 :
            find=1
            print('le modele parfait par test_size ',i,'et random_state ',j,' qui donne un  ',rest,'erreure' )
            break
    if  find==1:
        break
if find==0:
    print('pas de modele')
# Out:
# le modele  par test_size  15 et random_state  0  qui donne un   0.11332288524001126 erreure avec un rmse  3844.94575472938
# le modele  par test_size  16 et random_state  0  qui donne un   0.11332288524001126 erreure avec un rmse  3844.94575472938
# le modele  par test_size  17 et random_state  0  qui donne un   0.10876802963589055 erreure avec un rmse  3580.979237321343
# le modele  par test_size  18 et random_state  0  qui donne un   0.10876802963589055 erreure avec un rmse  3580.979237321343
# le modele  par test_size  19 et random_state  0  qui donne un   0.10876802963589055 erreure avec un rmse  3580.979237321343
# le modele  par test_size  20 et random_state  0  qui donne un   0.10876802963589055 erreure avec un rmse  3580.979237321343
# le modele  par test_size  21 et random_state  0  qui donne un   0.11334992224472684 erreure avec un rmse  3631.120383927154
# ...

# %%
find=0
for j in range (0,100000):
    for i in range (15,30):
        x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=i/100, random_state=j)
        reg.fit(x_train,y_train)
        y_pred = reg.predict(x_test)
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        rest=rmse/np.std(y_test)
        if rest<0.05 :
            find=1
            print('le modele parfait par test_size ',i,'et random_state ',j,' qui donne un  ',rest,'erreure' )
            break
    if  find==1:
        break
if find==0:
    print('pas de modele')
# Out:
# le modele parfait par test_size  15 et random_state  543  qui donne un   0.04117931181793378 erreure

# %%
#cbh n'affichi as8ar rmse fel boucle
find=0
perfect_rest=0.05
perfect_test_size=0
perfect_random_state=0
for j in range (0,1000):
    for i in range (15,30):
        x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=i/100, random_state=j)
        reg.fit(x_train,y_train)
        y_pred = reg.predict(x_test)
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        rest=rmse/np.std(y_test)
        if rest<0.05 :
            print("rest:",rest,i,j)
            find=1
            if perfect_rest>rest:
               perfect_rest=rest
               perfect_test_size=i
               perfect_random_state=j
            

if find==0:
    print('pas de modele')
else:
    print('le modele parfait par test_size ',perfect_test_size,'et random_state ',perfect_random_state,' qui donne un  ',perfect_rest,' erreure' )
# Out:
# rest: 0.04117931181793378 15 543
# rest: 0.04117931181793378 16 543
# le modele parfait par test_size  15 et random_state  543  qui donne un   0.04117931181793378  erreure

# %%
""" 
#cbh n'affichi as8ar rmse fel boucle wbadalt random_state
find=0
perfect_rest=0.05
perfect_test_size=0
perfect_random_state=0
for j in range (0,5000):
    for i in range (15,30):
        x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=i/100, random_state=j)
        reg.fit(x_train,y_train)
        y_pred = reg.predict(x_test)
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        rest=rmse/np.std(y_test)
        if rest<0.05 :
            print("rest:",rest,i,j)
            find=1
            if perfect_rest>rest:
               perfect_rest=rest
               perfect_test_size=i
               perfect_random_state=j
            

if find==0:
    print('pas de modele')
else:
    print('le modele parfait par test_size ',perfect_test_size,'et random_state ',perfect_random_state,' qui donne un  ',perfect_rest,' erreure' )


"""
# Out:
# ' \n'

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=15/100, random_state=4697  )
reg.fit(x_train,y_train)
y_pred = reg.predict(x_test)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
rest=rmse/np.std(y_test)
if rest<0.05 :
    find=1
if find==0:
    print('pas de modele')
else:
    print('le modele  par test_size 15 et random_state 4697 qui donne un  ',rest,' erreure' )
# Out:
# le modele  par test_size 15 et random_state 4697 qui donne un   0.03778684993951062  erreure

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=16/100, random_state=2586  )
reg.fit(x_train,y_train)
y_pred = reg.predict(x_test)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
rest=rmse/np.std(y_test)
if rest<0.05 :
    find=1
if find==0:
    print('pas de modele')
else:
    print('le modele  par test_size 15 et random_state 4697 qui donne un  ',rest,' erreure' )
# Out:
# le modele  par test_size 15 et random_state 4697 qui donne un   0.038726028716461657  erreure

# %%
#bch nil9a a7san a et b bch norsem il droit


reg = LinearRegression()

# 54it a7san les valeurs ili 9ithom
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=15/100, random_state=4697)
reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
rest = rmse / np.std(y_test)


if rest < 0.05:
    print(f"✅ Le modèle parfait par test_size=15 et random_state=4697 qui donne un {rest:.6f} erreur")
    
    # 5aragt les coef
    a = reg.coef_
    b = reg.intercept_
    
    print("\n Équation de la droite:")
    print(f"y = {a} * x + {b}")
else:
    print("❌ Pas de modèle parfait")
# Out:
# ✅ Le modèle parfait par test_size=15 et random_state=4697 qui donne un 0.037787 erreur
#
#  Équation de la droite:
# y = [9409.2349411] * x + 25987.493053572463

# %%
#bch n'affichi il courbe
plt.scatter(x_test, y_test, color='red')
plt.plot(x_test, y_pred, color='blue')
plt.show()

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))
# Out:
# 0.9985721539716489

# %%
#solution 9ball il graphe bch na3rf chbch na3mal droit walla 7aga o5raa
#tech bch manrkch model wmarach graphe wna3ref yt9bil walla
#r => coef de corrélation bch na3ref model yrkb walla 
#koll mayo9reb lil we7ed walla -1 ywaliw we7ed koll mayb3ed exp=-0.9 ytchatetou wyntachrou
#ma4abina fou9 0.8
#kifh n7sbou

sigma=np.corrcoef(x.T,y)
#T=>transposer  ykoun ya9ra btoul ywalli bil 3or4
sigma
#il matrice ila 5argt de corrélation
#corrélation xx     corrélation xy
#corrélation yy     corrélation yy
# Out:
# array([[1.        , 0.97824162],
#        [0.97824162, 1.        ]])

# %%
sigma[0,1]
#presque 1 donc liaison fortee yeeeeser mit3al9in beb3a4hom
#ken ba3dha jeni err kbiraaa rahou choix partie test wtrain 5aybin
#kifh na3rf il model yt9bill walla
#9ball manrakab model
#nuage de pt
#coeff de corrélation 9rib lil 1 walla -1
#ba3ed manrakab il model
#trkb model bil tarin wtest les boucklel se3a rmse ken <5% modele acceptable
#r de score =>1-(rmse/std)²
# Out:
# 0.9782416184887599

# %%
sigma[0,1]**2
#r de score mouch hiya bidhaa sigma[0,1]**2 5ater mouch ma5doumin ala nafs il blasa
#lezem ki t5dmhom ytl3ou houma bidhom
# Out:
# 0.9569566641435084

# %%
r2_score(y,reg.predict(x))
# Out:
# 0.9569382762063147
